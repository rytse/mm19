# %%
import numpy as np
import pandas as pd
from scipy.stats import norm, zscore
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import *
from sklearn.metrics.pairwise import sigmoid_kernel
from sklearn.metrics import log_loss
import itertools
import thutil

np.random.seed(1)

# V2U = ['Coach Tourney Appearances',
# 		'FG%',
# 		'Adj Off Efficiency',
# 		'Adj Def Efficiency',
# 		'Strength of Schedule',
# 		'Win %',
# 		'Major Conference',
# 		'Turnovers per game',
# 		'Wins Last 10 Games',
# 		'Coach Record',
# 		'Seed',
# 		'Won a Major Conference',
# 		'Rebounds']

V2U =  ['Seed',
'Wins Last 10 Games',
'Adj Def Efficiency',
'Adj Off Efficiency',
'Turnovers per game']

# Load all the game data
game_data = []
for year in range(2014, 2018+1):
	year = f'{year - 1}-{year}'
	rep = pd.read_csv(f'{year}_combo.csv')
	rep.rename(columns=lambda x: ' '.join(x.split()), inplace=True)
	rep[rep.select_dtypes(include=[np.number]).columns].apply(zscore)
	rep['pdiff'] = rep['Winner Points'] - rep['Loser points']
	rep['Winner'] = rep['Winner'] + '_' + year
	rep['Loser'] = rep['Loser'] + '_' + year
	game_data.append(rep)
game_data = pd.concat(game_data)

raw_names = [foo.strip() for foo in list(pd.read_csv('2014-2015_data.csv').columns)]
raw_names.remove('Team Name')

for i, row in game_data.iterrows():
	if np.random.random() > 0.5:
		for name in raw_names:
			vname_w = name + ' Winner'
			vname_l = name + ' Loser'
			wv = game_data.at[i, vname_w]
			game_data.at[i, vname_w] = game_data.at[i, vname_l]
			game_data.at[i, vname_l] = wv
		game_data.at[i, 'pdiff'] *= -1

def go(v2u, fi, sig1, sig2, ls1, ls2, ws, wl):
	# Set up winner, loser names for the selection of vars
	v2u_mod = []
	for v in v2u:
		v2u_mod.append(v + ' Winner')
		v2u_mod.append(v + ' Loser')

	# Set up Gaussian Process with its kernel (don't train yet)
	rbf1 = sig1 ** 2 * RBF(length_scale=ls1)
	rbf2 = sig2 ** 2 * RBF(length_scale=ls2)
	white = ws ** 2 * WhiteKernel(noise_level=wl**2)
	kernel = rbf1 + rbf2 + white

	gp = GaussianProcessRegressor(kernel,
# 		n_restarts_optimizer=10,
		normalize_y=True)

	lls = []
	for val_year in range(2014, 2018+1):
		val_year = f'{val_year - 1}-{val_year}'
		train = game_data[game_data['Winner'].str.endswith(val_year) == False]
		val = game_data[game_data['Winner'].str.endswith(val_year) == True]

		# Select the proper subsets of the dataframe
		X_train = train[v2u_mod]
		y_train = train['pdiff']
		X_val = val[v2u_mod]
		y_val = val['pdiff']

		gp.fit(X_train, y_train)	# train
		gp_y_pred, gp_sd = gp.predict(X_val, return_std=True)	# validate


		# Calculate validation log loss
		y_pred_probs = 1 - norm.cdf(-gp_y_pred / gp_sd)
		ll = log_loss(np.array(y_val > 0, dtype=np.int),
						np.array([1 - y_pred_probs, y_pred_probs]).T,
						labels=[0, 1])
		print(val_year + ': ' + str(ll))
		lls.append(ll)

# 	print(str(np.mean(lls)) + ', ' + str(v2u))
# 	fi.write(f'{np.mean(lls)}, {v2u}\n')

	return np.mean(lls)

sig1 = 3.2
sig2 = 3.2
ls1 = 93
ls2 = 93
ws = 1
wl = 1

# with open('ALOG.csv', 'a+') as fi:
# 	tp = thutil.ThreadPool(8)
# 	for nvars in range(3, 5+1):
# 	#for nvars in range(1, 3):
# 		for v2u in list(map(set, itertools.combinations(V2U, nvars))):
# 			tp.add_task(go, *(v2u, fi, sig1, sig2, ls1, ls2, ws, wl))
# 	tp.wait_completion()

# with open('tune.csv', 'a+') as fi:
# go(V2U, None, sig1, sig2, ls1, ls2, ws, wl)

# %%
best_ws = None
best_wl = None
best_ll = 1
for ws in np.linspace(0, 5, 20):
    print('x')
    for wl in np.linspace(0, 5, 20):
        ll = go(V2U, None, sig1, sig2, ls1, ls2, ws, wl)
        if ll < best_ll:
            best_ll = ll
            best_ws = ws
            best_wl = wl

print(f'Best WS: {best_ws}')
print(f'Best WL: {best_wl}')
# Out:
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00418684, -0.        ,  0.00418684, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-8.03285189e-05, -0.00000000e+00, -8.03285189e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 112, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00273015, -0.        ,  0.00273015, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 75, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00759233, -0.        ,  0.00759233, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 75, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.68580169e-05, -0.00000000e+00, -1.68580169e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 65, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 6.97745153e-05, -0.00000000e+00,  6.97745153e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 93, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00141446, -0.        ,  0.00141446, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 117, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 1.70469215e-05, -0.00000000e+00,  1.70469215e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 106, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00796315, -0.        ,  0.00796315, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00351184, -0.        , -0.00351184, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 80, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.01302552, -0.        ,  0.01302552, -0.        ,  0.25008438,
#         0.25008438]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 68, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.26850157e-05, -0.00000000e+00,  3.26850157e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 69, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.02627153, -0.        , -0.02627153, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.10493699e-05, -0.00000000e+00,  3.10493699e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 67, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00588427, -0.        , -0.00588427, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 71, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 5.81089585e-05, -0.00000000e+00,  5.81089585e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 73, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.03073778, -0.        ,  0.03073778, -0.        ,  0.25008438,
#         0.25008438]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 107, 'nit': 19, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.02460524, -0.        , -0.02460524, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.01197563, -0.        ,  0.01197563, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 80, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00039404, -0.        ,  0.00039404, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 93, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00292597, -0.        ,  0.00292597, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 84, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00861639, -0.        ,  0.00861639, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 9, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00282189, -0.        ,  0.00282189, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.18520884e-05, -0.00000000e+00,  3.18520884e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 100, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 9.84612746e-05, -0.00000000e+00,  9.84612746e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 72, 'nit': 22, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00637625, -0.        , -0.00637625, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 65, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00244567, -0.        , -0.00244567, -0.        ,  0.25008438,
#         0.25008438]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00139213, -0.        , -0.00139213, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00094162, -0.        ,  0.00094162, -0.        ,  0.25008438,
#         0.25008438]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 71, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00102379, -0.        ,  0.00102379, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 63, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00187132, -0.        , -0.00187132, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 92, 'nit': 19, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00305153, -0.        , -0.00305153, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00047043, -0.        , -0.00047043, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 76, 'nit': 11, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00372648, -0.        , -0.00372648, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-4.07426073e-05, -0.00000000e+00, -4.07426073e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 73, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00562029, -0.        , -0.00562029, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 77, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.3295605e-04, -0.0000000e+00, -1.3295605e-04, -0.0000000e+00,
#         2.5006661e-01,  2.5006661e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 106, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.00580536e-05, -0.00000000e+00,  3.00580536e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.73755348e-05, -0.00000000e+00, -2.73755348e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 79, 'nit': 19, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00348398, -0.        , -0.00348398, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 84, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.03630033, -0.        , -0.03630033, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 74, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00148429, -0.        , -0.00148429, -0.        ,  0.25004884,
#         0.25004884]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 76, 'nit': 24, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 5.65950825e-05, -0.00000000e+00,  5.65950825e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 12, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00043272, -0.        ,  0.00043272, -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 5.82775713e-05, -0.00000000e+00,  5.82775713e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 60, 'nit': 11, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.0005832 , -0.        , -0.0005832 , -0.        ,  0.25006661,
#         0.25006661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 93, 'nit': 25, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-6.09083207e-05, -0.00000000e+00, -6.09083207e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 65, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.65823437e-05, -0.00000000e+00, -2.65823437e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 63, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.
]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 55, 'nit': 5, 'warnflag': 2}
#   ConvergenceWarning)
# Best WS: 1.8421052631578947
# Best WL: 2.3684210526315788

# %%
best_ll
# Out:
# 0.5149891016544332

# %%
best_ls1m = None
best_ls2m = None

for ls1m in np.linspace(0, 2, 20):
    print('x')
    for ls2m in np.linspace(0, 2, 20):
        ll = go(V2U, None, sig1, sig2, ls1 * ls1m, ls2 * ls2m, best_ws, best_wl)
        if ll < best_ll:
            best_ll = ll
            best_ls1m = ls1m
            best_ls2m = ls2m


print(f'Best WS: {best_ws}')
print(f'Best WL: {best_wl}')
# Out:
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.76675183e-05, -0.00000000e+00,  3.76675183e-05, -0.00000000e+00,
#         2.50066610e-01,  2.50066610e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 71, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.02259904, -0.        , -0.00378693,  0.00500397,  0.25020888,
#         0.25020888]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 87, 'nit': 37, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 1.10439177e-02, -0.00000000e+00,  1.67057675e-03, -6.76883065e-06,
#         2.50173294e-01,  2.50173294e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 86, 'nit': 33, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.02344469, -0.        ,  0.00067647, -0.00279566,  0.25036912,
#         0.25036912]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 105, 'nit': 43, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.97602936e-04, -0.00000000e+00, -5.52518629e-04, -8.78247738e-05,
#         2.50084385e-01,  2.50084385e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 90, 'nit': 38, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00211922, -0.        ,  0.00042867, -0.00029498,  0.25022667,
#         0.25022667]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 89, 'nit': 40, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.03187344, -0.        ,  0.00282691, -0.01921489,  0.25023557,
#         0.25023557]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 134, 'nit': 49, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.01038252, -0.        ,  0.01979733, -0.00265714,  0.25024447,
#         0.25024447]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 190, 'nit': 41, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 5.35611705e-04, -0.00000000e+00,  1.68703491e-04, -4.17241969e-04,
#         2.50182189e-01,  2.50182189e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 105, 'nit': 37, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00215875, -0.        ,  0.00043513, -0.00059215,  0.25020888,
#         0.25020888]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 170, 'nit': 46, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.05701226, -0.        , -0.01629556, -0.01824846,  0.2501644 ,
#         0.2501644 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 97, 'nit': 35, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.0418814 , -0.        ,  0.01039935,  0.0213429 ,  0.25015551,
#         0.25015551]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 85, 'nit': 29, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.58627915e-03, -0.00000000e+00, -5.54362519e-04, -1.31450237e-04,
#         2.50128832e-01,  2.50128832e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 82, 'nit': 35, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.09526918, -0.        , -0.0078224 ,  0.04793769,  0.25017329,
#         0.25017329]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 92, 'nit': 38, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00267633, -0.        , -0.00123858,  0.00470401,  0.25017329,
#         0.25017329]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 72, 'nit': 26, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00175945, -0.        ,  0.00362647,  0.01068991,  0.25011994,
#         0.25011994]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 93, 'nit': 32, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00738688, -0.        , -0.00214714,  0.00726564,  0.25017329,
#         0.25017329]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 90, 'nit': 27, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00885187, -0.        , -0.00229938,  0.01378809,  0.25020888,
#         0.25020888]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 106, 'nit': 44, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.01460364, -0.        ,  0.01052028, -0.04675893,  0.25018219,
#         0.25018219]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 124, 'nit': 32, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 7.31534431e-05, -0.00000000e+00, -4.92605701e-04,  3.39156130e-03,
#         2.50208876e-01,  2.50208876e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 105, 'nit': 32, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.01490086e-03, -0.00000000e+00,  5.32025355e-06,  4.92147280e-04,
#         2.50173294e-01,  2.50173294e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 73, 'nit': 27, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.0018744 , -0.        , -0.00207295, -0.00194088,  0.25033349,
#         0.25033349]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 72, 'nit': 27, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 8.32483983e-05, -0.00000000e+00, -4.93871474e-03, -7.37657621e-03,
#         2.50173294e-01,  2.50173294e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 86, 'nit': 26, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.06492489, -0.        , -0.01135044, -0.00249801,  0.25025337,
#         0.25025337]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 118, 'nit': 36, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00190403, -0.        ,  0.00317475, -0.00223859,  0.25019108,
#         0.25019108]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 77, 'nit': 29, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00820537, -0.        ,  0.00031528, -0.01525672,  0.25013772,
#         0.25013772]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 86, 'nit': 30, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.84914889e-04, -0.00000000e+00, -4.90205869e-05, -2.97244685e-05,
#         2.50191084e-01,  2.50191084e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 102, 'nit': 33, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.
), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 106, 'nit': 33, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.01221326, -0.02482101, -0.02320517, -0.        ,  0.25019998,
#         0.25019998]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 127, 'nit': 33, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 3.60948200e-04, -1.77951819e-04, -1.64460551e-03, -6.39985728e-04,
#         2.50226670e-01,  2.50226670e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 109, 'nit': 36, 'warnflag': 2}
#   ConvergenceWarning)
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.03825695, -0.12115524,  0.14899054, -0.        ,  0.25017329,
#         0.25017329]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 83, 'nit': 33, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.01118713, -0.00069847,  0.0151889 , -0.        ,  0.25011994,
#         0.25011994]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 104, 'nit': 36, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 1.42307254e-06, -3.15728883e-06,  3.07513024e-05, -0.00000000e+00,
#         2.50217773e-01,  2.50217773e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 164, 'nit': 46, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00100891,  0.0127363 ,  0.00868719, -0.        ,  0.25020888,
#         0.25020888]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 100, 'nit': 33, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84696334e-02, -1.36763258e-02,  3.11083725e-03, -1.00223986e-04,
#         2.50217773e-01,  2.50217773e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 117, 'nit': 34, 'warnflag': 2}
#   ConvergenceWarning)
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 1.99402345e-04, -7.60825613e-04,  3.79316297e-03, -0.00000000e+00,
#         2.50173294e-01,  2.50173294e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 95, 'nit': 36, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.02019758, -0.02312875,  0.01650107,  0.00120465,  0.2501644 ,
#         0.2501644 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 110, 'nit': 34, 'warnflag': 2}
#   ConvergenceWarning)
# x
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.00296955,  0.00655731,  0.03959247, -0.        ,  0.25031568,
#         0.25031568]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 129, 'nit': 38, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 0.00282947, -0.01359728, -0.0023618 , -0.        ,  0.25015551,
#         0.25015551]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 95, 'nit': 38, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py:247: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.hstack(theta))
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.0032105 ,  0.00981634,  0.08734893, -0.        ,  0.25017329,
#         0.25017329]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 115, 'nit': 39, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.02783207,  0.00434592, -0.06912915,  0.00857135,  0.25014661,
#         0.25014661]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 113, 'nit': 31, 'warnflag': 2}
#   ConvergenceWarning)
# /home/rytse/anaconda3/envs/mm/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ 5.46364767e-05, -9.05993966e-03,  8.01922384e-04, -0.00000000e+00,
#         2.50155507e-01,  2.50155507e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 91, 'nit': 31, 'warnflag': 2}
#   ConvergenceWarning)
# Best WS: 1.8421052631578947
# Best WL: 2.3684210526315788

# %%
print(f'Best LS1M: {best_ls1m}')
print(f'Best LS2M: {best_ls2m}')
# Out:
# Best LS1M: 0.631578947368421
# Best LS2M: 0.3157894736842105

# %%
def go(v2u, fi, sig1, sig2, ls1, ls2, ws, wl):
	# Set up winner, loser names for the selection of vars
	v2u_mod = []
	for v in v2u:
		v2u_mod.append(v + ' Winner')
		v2u_mod.append(v + ' Loser')

	# Set up Gaussian Process with its kernel (don't train yet)
	rbf1 = sig1 ** 2 * RBF(length_scale=ls1)
	rbf2 = sig2 ** 2 * RBF(length_scale=ls2)
	white = ws ** 2 * WhiteKernel(noise_level=wl**2)
	kernel = rbf1 + rbf2 + white

	gp = GaussianProcessRegressor(kernel,
# 		n_restarts_optimizer=10,
		normalize_y=True)

	lls = []
	for val_year in [2014, 2015, 2017]:#range(2014, 2018+1):
		val_year = f'{val_year - 1}-{val_year}'
		train = game_data[game_data['Winner'].str.endswith(val_year) == False]
		val = game_data[game_data['Winner'].str.endswith(val_year) == True]

		# Select the proper subsets of the dataframe
		X_train = train[v2u_mod]
		y_train = train['pdiff']
		X_val = val[v2u_mod]
		y_val = val['pdiff']

		gp.fit(X_train, y_train)	# train
		gp_y_pred, gp_sd = gp.predict(X_val, return_std=True)	# validate


		# Calculate validation log loss
		y_pred_probs = 1 - norm.cdf(-gp_y_pred / gp_sd)
		ll = log_loss(np.array(y_val > 0, dtype=np.int),
						np.array([1 - y_pred_probs, y_pred_probs]).T,
						labels=[0, 1])
		print(val_year + ': ' + str(ll))
		lls.append(ll)

# 	print(str(np.mean(lls)) + ', ' + str(v2u))
# 	fi.write(f'{np.mean(lls)}, {v2u}\n')

	return np.mean(lls)

# %%
go(V2U, None, sig1, sig2, ls1 * best_ls1m, ls2 * best_ls2m, best_ws, best_wl)
# Out:
# 2013-2014: 0.5182266544313968
# 2014-2015: 0.4495148746180374
# 2016-2017: 0.41701733448107425
# 0.46158628784350286

# %%
v2u_mod = []
for v in V2U:
    v2u_mod.append(v + ' Winner')
    v2u_mod.append(v + ' Loser')

train = game_data[game_data['Winner'].str.endswith('2014') == False]
train = train[train['Winner'].str.endswith('2015') == False]
train = train[train['Winner'].str.endswith('2017') == False]
val = game_data[game_data['Winner'].str.endswith('2016') == False]
val = val[val['Winner'].str.endswith('2018') == False]

# Select the proper subsets of the dataframe
X_train = train[v2u_mod]
y_train = train['pdiff']
X_val = val[v2u_mod]
y_val = val['pdiff']

rbf1 = sig1 ** 2 * RBF(length_scale=ls1 * ls1m)
rbf2 = sig2 ** 2 * RBF(length_scale=ls2 * ls2m)
white = ws ** 2 * WhiteKernel(noise_level=wl**2)
kernel = rbf1 + rbf2 + white

gp = GaussianProcessRegressor(kernel,
# 		n_restarts_optimizer=10,
    normalize_y=True)

gp.fit(X_train, y_train)    # train
gp_y_pred, gp_sd = gp.predict(X_val, return_std=True)    # validate

# Calculate validation log loss
y_pred_probs = 1 - norm.cdf(-gp_y_pred / gp_sd)
ll = log_loss(np.array(y_val > 0, dtype=np.int),
            np.array([1 - y_pred_probs, y_pred_probs]).T,
            labels=[0, 1])
print(str(ll))
# Out:
# 0.5079430820607647

# %%
v2u_mod = []
for v in V2U:
    v2u_mod.append(v + ' Winner')
    v2u_mod.append(v + ' Loser')

train = game_data#[game_data['Winner'].str.endswith('2016') == False]
# train = train[train['Winner'].str.endswith('2018') == False]
val = game_data[game_data['Winner'].str.endswith('2014') == False]
val = val[val['Winner'].str.endswith('2015') == False]
val = val[val['Winner'].str.endswith('2017') == False]

# Select the proper subsets of the dataframe
X_train = train[v2u_mod]
y_train = train['pdiff']
X_val = val[v2u_mod]
y_val = val['pdiff']

rbf1 = sig1 ** 2 * RBF(length_scale=ls1*ls1m)
rbf2 = sig2 ** 2 * RBF(length_scale=ls2*ls2m)
white = ws ** 2 * WhiteKernel(noise_level=wl**2)
kernel = rbf1 + rbf2 + white

gp = GaussianProcessRegressor(kernel,
# 		n_restarts_optimizer=10,
    normalize_y=True)

gp.fit(X_train, y_train)    # train
gp_y_pred, gp_sd = gp.predict(X_val, return_std=True)    # validate

# Calculate validation log loss
y_pred_probs = 1 - norm.cdf(-gp_y_pred / gp_sd)
ll = log_loss(np.array(y_val > 0, dtype=np.int),
            np.array([1 - y_pred_probs, y_pred_probs]).T,
            labels=[0, 1])
print(str(ll))
# Out:
# 0.48021433665329283
